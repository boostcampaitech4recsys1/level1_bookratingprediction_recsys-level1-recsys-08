# %% [markdown]
# ## hitmap을 이용한 corr 시각화(age 위주)

# %%
import re
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, Dataset
import seaborn as sns
import matplotlib.pyplot as plt

# %%
users = pd.read_csv('../data/' + 'users.csv')
books = pd.read_csv('../data/' + 'books.csv')
train = pd.read_csv('../data/' + 'train_ratings.csv')
test = pd.read_csv('../data/' + 'test_ratings.csv')
sub = pd.read_csv('../data/' + 'sample_submission.csv')

# %%
users = users.dropna(subset=['age'])

# %%
def make_category_high(books:pd.DataFrame) -> pd.DataFrame:
    books.loc[books[books['category'].notnull()].index, 'category'] = books[books['category'].notnull()]['category'].apply(lambda x: re.sub('[\W_]+',' ',x).strip())
    books['category'] = books['category'].str.lower()
    categories = ['garden','crafts','physics','adventure','music','fiction','nonfiction','science','science fiction','social','homicide',
    'sociology','disease','religion','christian','philosophy','psycholog','mathemat','agricult','environmental',
    'business','poetry','drama','literary','travel','motion picture','children','cook','literature','electronic',
    'humor','animal','bird','photograph','computer','house','ecology','family','architect','camp','criminal','language','india']

    books['category_high'] = books['category'].copy()
    for category in categories:
        books.loc[books[books['category'].str.contains(category,na=False)].index,'category_high'] = category
        
    category_high_df = pd.DataFrame(books['category_high'].value_counts()).reset_index()
    category_high_df.columns = ['category','count']
    others_list = category_high_df[category_high_df['count']<5]['category'].values
    books.loc[books[books['category_high'].isin(others_list)].index, 'category_high']='others'
    return books
books = make_category_high(books)

# %%
test_df = train.merge(users, how="left", on='user_id')
test_df = test_df.merge(books, how="left", on='isbn')

# %%
def age_map(x: int) -> int:
    x = int(x)
    if x < 20:
        return 1
    elif x >= 20 and x < 30:
        return 2
    elif x >= 30 and x < 40:
        return 3
    elif x >= 40 and x < 50:
        return 4
    elif x >= 50 and x < 60:
        return 5
    else:
        return 6

# %%
test_df
# Out:
#         user_id        isbn  rating                      location   age  \
# 0             8  0002005018       4                           NaN   NaN
# 1         67544  0002005018       7      toronto, ontario, canada  30.0
# 2        123629  0002005018       8                           NaN   NaN
# 3        200273  0002005018       8                           NaN   NaN
# 4        210926  0002005018       9                           NaN   NaN
# ...         ...         ...     ...                           ...   ...
# 306790   278843  0743525493       7  pismo beach, california, usa  28.0
# 306791   278851  067161746X       6            dallas, texas, usa  33.0
# 306792   278851  0884159221       7            dallas, texas, usa  33.0
# 306793   278851  0912333022       7            dallas, texas, usa  33.0
# 306794   278851  1569661057      10            dallas, texas, usa  33.0
#
#                                                book_title  \
# 0                                            Clara Callan
# 1                                            Clara Callan
# 2                                            Clara Callan
# 3                                            Clara Callan
# 4                                            Clara Callan
# ...                                                   ...
# 306790  The Motley Fool's What To Do with Your Money N...
# 306791  The Bachelor Home Companion: A Practical Guide...
# 306792  Why stop?: A guide to Texas historical roadsid...
# 306793  The Are You Being Served? Stories: 'Camping In...
# 306794  Dallas Street Map Guide and Directory, 2000 Ed...
#
#                  book_author  year_of_publication                 publisher  \
# 0       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 1       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 2       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 3       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 4       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# ...                      ...                  ...                       ...
# 306790         David Gardner               2002.0    Simon & Schuster Audio
# 306791         P.J. O'Rourke               1987.0              Pocket Books
# 306792         Claude Dooley               1985.0           Lone Star Books
# 306793          Jeremy Lloyd               1997.0                Kqed Books
# 306794                Mapsco               1999.0  American Map Corporation
#
#                                                   img_url language   category  \
# 0       http://images.amazon.com/images/P/0002005018.0...       en  actresses
# 1       http://images.amazon.com/images/P/0002005018.0...       en  actresses
# 2       http://images.amazon.com/images/P/0002005018.0...       en  actresses
# 3       http://images.amazon.com/images/P/0002005018.0...       en  actresses
# 4       http://images.amazon.com/images/P/0002005018.0...       en  actresses
# ...                                                   ...      ...        ...
# 306790  http://images.amazon.com/images/P/0743525493.0...      NaN        NaN
# 306791  http://images.amazon.com/images/P/067161746X.0...       en      humor
# 306792  http://images.amazon.com/images/P/0884159221.0...      NaN        NaN
# 306793  http://images.amazon.com/images/P/0912333022.0...       en    fiction
# 306794  http://images.amazon.com/images/P/1569661057.0...      NaN        NaN
#
#                                                   summary  \
# 0       In a small town in Canada, Clara Callan reluct...
# 1       In a small town in Canada, Clara Callan reluct...
# 2       In a small town in Canada, Clara Callan reluct...
# 3       In a small town in Canada, Clara Callan reluct...
# 4       In a small town in Canada, Clara Callan reluct...
# ...                                                   ...
# 306790                                                NaN
# 306791  A tongue-in-cheek survival guide for single pe...
# 306792                                                NaN
# 306793  These hilarious stories by the creator of publ...
# 306794                                                NaN
#
#                                  img_path category_high
# 0       images/0002005018.01.THUMBZZZ.jpg     actresses
# 1       images/0002005018.01.THUMBZZZ.jpg     actresses
# 2       images/0002005018.01.THUMBZZZ.jpg     actresses
# 3       images/0002005018.01.THUMBZZZ.jpg     actresses
# 4       images/0002005018.01.THUMBZZZ.jpg     actresses
# ...                                   ...           ...
# 306790  images/0743525493.01.THUMBZZZ.jpg           NaN
# 306791  images/067161746X.01.THUMBZZZ.jpg         humor
# 306792  images/0884159221.01.THUMBZZZ.jpg           NaN
# 306793  images/0912333022.01.THUMBZZZ.jpg       fiction
# 306794  images/1569661057.01.THUMBZZZ.jpg           NaN
#
# [306795 rows x 15 columns]

# %%
test_df['location'] = test_df['location'].fillna(",,").astype(str)

# %%
test_df['location_city'] = test_df['location'].apply(lambda x: x.split(',')[0])
test_df['location_state'] = test_df['location'].apply(lambda x: x.split(',')[1])
test_df['location_country'] = test_df['location'].apply(lambda x: x.split(',')[2])
test_df = test_df.drop(['location'], axis=1)

# %%
test_df['book_author'] = test_df['book_author'].str.replace('.','', regex=True)
test_df['book_author'] = test_df['book_author'].str.replace('_',' ', regex=True)
test_df['book_author'] = test_df['book_author'].str.lower()
test_df['book_author'] = test_df['book_author'].apply(lambda x:' '.join(sorted(x.split())))

# %%
loc_city2idx = {v:k for k,v in enumerate(test_df['location_city'].unique())}
loc_state2idx = {v:k for k,v in enumerate(test_df['location_state'].unique())}
loc_country2idx = {v:k for k,v in enumerate(test_df['location_country'].unique())}
category2idx = {v:k for k,v in enumerate(test_df['category'].unique())}
categoryhigh2idx = {v:k for k,v in enumerate(test_df['category_high'].unique())}
publisher2idx = {v:k for k,v in enumerate(test_df['publisher'].unique())}
language2idx = {v:k for k,v in enumerate(test_df['language'].unique())}
author2idx = {v:k for k,v in enumerate(test_df['book_author'].unique())}

# %%
test_df['location_city'] = test_df['location_city'].map(loc_city2idx)
test_df['location_state'] = test_df['location_state'].map(loc_state2idx)
test_df['location_country'] = test_df['location_country'].map(loc_country2idx)
test_df['age'] = test_df['age'].fillna(int(test_df['age'].mean()))
test_df['age'] = test_df['age'].apply(age_map)
test_df['category'] = test_df['category'].map(category2idx)
test_df['category_high'] = test_df['category_high'].map(categoryhigh2idx)
test_df['publisher'] = test_df['publisher'].map(publisher2idx)
test_df['language'] = test_df['language'].map(language2idx)
test_df['book_author'] = test_df['book_author'].map(author2idx)

# %%
test_df
# Out:
#         user_id        isbn  rating  age  \
# 0             8  0002005018       4    3
# 1         67544  0002005018       7    3
# 2        123629  0002005018       8    3
# 3        200273  0002005018       8    3
# 4        210926  0002005018       9    3
# ...         ...         ...     ...  ...
# 306790   278843  0743525493       7    2
# 306791   278851  067161746X       6    3
# 306792   278851  0884159221       7    3
# 306793   278851  0912333022       7    3
# 306794   278851  1569661057      10    3
#
#                                                book_title  book_author  \
# 0                                            Clara Callan            0
# 1                                            Clara Callan            0
# 2                                            Clara Callan            0
# 3                                            Clara Callan            0
# 4                                            Clara Callan            0
# ...                                                   ...          ...
# 306790  The Motley Fool's What To Do with Your Money N...         1215
# 306791  The Bachelor Home Companion: A Practical Guide...           67
# 306792  Why stop?: A guide to Texas historical roadsid...        52403
# 306793  The Are You Being Served? Stories: 'Camping In...        52404
# 306794  Dallas Street Map Guide and Directory, 2000 Ed...        52405
#
#         year_of_publication  publisher  \
# 0                    2001.0          0
# 1                    2001.0          0
# 2                    2001.0          0
# 3                    2001.0          0
# 4                    2001.0          0
# ...                     ...        ...
# 306790               2002.0       2171
# 306791               1987.0        222
# 306792               1985.0      10406
# 306793               1997.0       6387
# 306794               1999.0      10407
#
#                                                   img_url  language  category  \
# 0       http://images.amazon.com/images/P/0002005018.0...         0         0
# 1       http://images.amazon.com/images/P/0002005018.0...         0         0
# 2       http://images.amazon.com/images/P/0002005018.0...         0         0
# 3       http://images.amazon.com/images/P/0002005018.0...         0         0
# 4       http://images.amazon.com/images/P/0002005018.0...         0         0
# ...                                                   ...       ...       ...
# 306790  http://images.amazon.com/images/P/0743525493.0...         1         5
# 306791  http://images.amazon.com/images/P/067161746X.0...         0         7
# 306792  http://images.amazon.com/images/P/0884159221.0...         1         5
# 306793  http://images.amazon.com/images/P/0912333022.0...         0         3
# 306794  http://images.amazon.com/images/P/1569661057.0...         1         5
#
#                                                   summary  \
# 0       In a small town in Canada, Clara Callan reluct...
# 1       In a small town in Canada, Clara Callan reluct...
# 2       In a small town in Canada, Clara Callan reluct...
# 3       In a small town in Canada, Clara Callan reluct...
# 4       In a small town in Canada, Clara Callan reluct...
# ...                                                   ...
# 306790                                                NaN
# 306791  A tongue-in-cheek survival guide for single pe...
# 306792                                                NaN
# 306793  These hilarious stories by the creator of publ...
# 306794                                                NaN
#
#                                  img_path  category_high  location_city  \
# 0       images/0002005018.01.THUMBZZZ.jpg              0              0
# 1       images/0002005018.01.THUMBZZZ.jpg              0              1
# 2       images/0002005018.01.THUMBZZZ.jpg              0              0
# 3       images/0002005018.01.THUMBZZZ.jpg              0              0
# 4       images/0002005018.01.THUMBZZZ.jpg              0              0
# ...                                   ...            ...            ...
# 306790  images/0743525493.01.THUMBZZZ.jpg              5           1246
# 306791  images/067161746X.01.THUMBZZZ.jpg              7            340
# 306792  images/0884159221.01.THUMBZZZ.jpg              5            340
# 306793  images/0912333022.01.THUMBZZZ.jpg              3            340
# 306794  images/1569661057.01.THUMBZZZ.jpg              5            340
#
#         location_state  location_country
# 0                    0                 0
# 1                    1                 1
# 2                    0                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 306790               6                 2
# 306791               9                 2
# 306792               9                 2
# 306793               9                 2
# 306794               9                 2
#
# [306795 rows x 17 columns]

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(test_df[['age','rating','category_high', 'book_author']].corr(), linewidths=0.1, vmax=1, cmap='RdYlBu_r', linecolor='white',annot=True)
plt.show()
# Out:
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3745, in atexit_operations
#     self._atexit_once()
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3724, in _atexit_once
#     self.reset(new_session=False)
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 1339, in reset
#     self.history_manager.reset(new_session)
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/history.py", line 594, in reset
#     self.dir_hist[:] = [Path.cwd()]
#   File "/opt/conda/lib/python3.8/pathlib.py", line 1092, in cwd
#     return cls(os.getcwd())
# FileNotFoundError: [Errno 2] No such file or directory
