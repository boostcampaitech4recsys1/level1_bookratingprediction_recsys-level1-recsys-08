# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, Dataset
import seaborn as sns
import matplotlib.pyplot as plt

# %%
users = pd.read_csv('./data/' + 'users.csv')
books = pd.read_csv('./data/' + 'books.csv')
train = pd.read_csv('./data/' + 'train_ratings.csv')
test = pd.read_csv('./data/' + 'test_ratings.csv')
sub = pd.read_csv('./data/' + 'sample_submission.csv')

# %%
df_nan_summary = books[books['summary'].isnull()]
df_exist_summary = books[books['summary'].notnull()]

# %%
df_nan_summary = train.merge(df_nan_summary, how='left', on='isbn')
# Out:
#         user_id        isbn  rating  \
# 0             8  0002005018       4
# 1         67544  0002005018       7
# 2        123629  0002005018       8
# 3        200273  0002005018       8
# 4        210926  0002005018       9
# ...         ...         ...     ...
# 306790   278843  0743525493       7
# 306791   278851  067161746X       6
# 306792   278851  0884159221       7
# 306793   278851  0912333022       7
# 306794   278851  1569661057      10
#
#                                                book_title    book_author  \
# 0                                                     NaN            NaN
# 1                                                     NaN            NaN
# 2                                                     NaN            NaN
# 3                                                     NaN            NaN
# 4                                                     NaN            NaN
# ...                                                   ...            ...
# ...

# %%
df_nan_summary['rating'].mean()
# Out:
# 7.069714304340032

# %%
df_exist_summary = train.merge(df_exist_summary, how='left', on='isbn')

# %%
df_exist_summary['rating'].mean()
# Out:
# 7.069714304340032
