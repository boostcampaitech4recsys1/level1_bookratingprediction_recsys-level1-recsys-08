# %% [markdown]
# # book_author preprocessing performance

# %%
# !python main.py --MODEL FM     #전 : loss(1.46), rmse(2.3480)
# Out:
# --------------- FM Load Data ---------------
# --------------- FM Train/Valid Split ---------------
# --------------- INIT FM ---------------
# --------------- FM TRAINING ---------------
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 77.04it/s]
# epoch: 0 validation: rmse: 2.795825610151498
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 83.87it/s]
# epoch: 1 validation: rmse: 2.5146528636031964
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 84.27it/s]
# epoch: 2 validation: rmse: 2.410375075717811
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 84.56it/s]
# epoch: 3 validation: rmse: 2.3658030251139843
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 98.40it/s]
# epoch: 4 validation: rmse: 2.3480359870285485
# ...
# 100%|██████████████████████████████████████████| 60/60 [00:00<00:00, 110.90it/s]
# epoch: 5 validation: rmse: 2.34863912930756
# ...

# %%
# !python main.py --MODEL FM     #후 : loss(1.45), rmse(2.3290)
# Out:
# --------------- FM Load Data ---------------
# --------------- FM Train/Valid Split ---------------
# --------------- INIT FM ---------------
# --------------- FM TRAINING ---------------
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 95.44it/s]
# epoch: 0 validation: rmse: 2.685723314187398
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 82.59it/s]
# epoch: 1 validation: rmse: 2.4524858475739317
# ...
# 100%|██████████████████████████████████████████| 60/60 [00:00<00:00, 106.86it/s]
# epoch: 2 validation: rmse: 2.3689548985345334
# ...
# 100%|██████████████████████████████████████████| 60/60 [00:00<00:00, 107.74it/s]
# epoch: 3 validation: rmse: 2.335415673835371
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 95.02it/s]
# epoch: 4 validation: rmse: 2.325064296912299
# ...
# 100%|██████████████████████████████████████████| 60/60 [00:00<00:00, 106.44it/s]
# epoch: 5 validation: rmse: 2.3290035089253203
# ...

# %%
# !python main.py --MODEL FFM     #전 : loss(0.603), rmse(2.3967)
# Out:
# --------------- FFM Load Data ---------------
# --------------- FFM Train/Valid Split ---------------
# --------------- INIT FFM ---------------
# --------------- FFM TRAINING ---------------
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 80.65it/s]
# epoch: 0 validation: rmse: 2.6960028564164396
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 90.28it/s]
# epoch: 1 validation: rmse: 2.418665504819991
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 90.06it/s]
# epoch: 2 validation: rmse: 2.3967727582564358
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 90.39it/s]
# epoch: 3 validation: rmse: 2.4008866276452556
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 82.37it/s]
# epoch: 4 validation: rmse: 2.410613537559563
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 90.34it/s]
# epoch: 5 validation: rmse: 2.4146200034629786
# ...

# %%
# !python main.py --MODEL FFM     #후 : loss(0.609), rmse(2.3927)
# Out:
# --------------- FFM Load Data ---------------
# --------------- FFM Train/Valid Split ---------------
# --------------- INIT FFM ---------------
# --------------- FFM TRAINING ---------------
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 81.48it/s]
# epoch: 0 validation: rmse: 2.693524659016368
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 90.01it/s]
# epoch: 1 validation: rmse: 2.4150126383541983
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 89.57it/s]
# epoch: 2 validation: rmse: 2.3927152498391924
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 91.37it/s]
# epoch: 3 validation: rmse: 2.4039918100521787
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 81.13it/s]
# epoch: 4 validation: rmse: 2.410636623549159
# ...
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 91.35it/s]
# epoch: 5 validation: rmse: 2.418837457792354
# ...
